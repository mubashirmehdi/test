# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder

# %%
data=pd.read_csv('C:/Users/HP/Downloads/AI-Data.csv')
data.head(480)
# Out:
#     gender NationalITy PlaceofBirth       StageID GradeID SectionID  \
# 0        M          KW       KuwaIT    lowerlevel    G-04         A
# 1        M          KW       KuwaIT    lowerlevel    G-04         A
# 2        M          KW       KuwaIT    lowerlevel    G-04         A
# 3        M          KW       KuwaIT    lowerlevel    G-04         A
# 4        M          KW       KuwaIT    lowerlevel    G-04         A
# ..     ...         ...          ...           ...     ...       ...
# 475      F      Jordan       Jordan  MiddleSchool    G-08         A
# 476      F      Jordan       Jordan  MiddleSchool    G-08         A
# 477      F      Jordan       Jordan  MiddleSchool    G-08         A
# 478      F      Jordan       Jordan  MiddleSchool    G-08         A
# 479      F      Jordan       Jordan  MiddleSchool    G-08         A
#
#          Topic Semester Relation  raisedhands  VisITedResources  \
# 0           IT        F   Father           15                16
# ...

# %%
print('percentage',data.GradeID.value_counts(normalize=True))
data.gender.value_counts(normalize=True).plot(kind='pie')
# Out:
# percentage G-02    0.306250
# G-08    0.241667
# G-07    0.210417
# G-04    0.100000
# G-06    0.066667
# G-11    0.027083
# G-12    0.022917
# G-09    0.010417
# G-10    0.008333
# G-05    0.006250
# Name: GradeID, dtype: float64
# <Axes: ylabel='gender'>

# %%
print('percentage',data.raisedhands.value_counts(normalize=True))
data.raisedhands.value_counts(normalize=True).plot(kind='pie',figsize=(20,20),fontsize=30)
# Out:
# percentage 10    0.064583
# 70    0.064583
# 80    0.058333
# 72    0.035417
# 50    0.035417
#         ...
# 61    0.002083
# 83    0.002083
# 52    0.002083
# 67    0.002083
# 97    0.002083
# Name: raisedhands, Length: 82, dtype: float64
# <Axes: ylabel='raisedhands'>

# %%
print('percentage',data.ParentAnsweringSurvey.value_counts(normalize=True))
data.ParentAnsweringSurvey.value_counts(normalize=True).plot(kind='pie',fontsize=30)
# Out:
# percentage Yes    0.5625
# No     0.4375
# Name: ParentAnsweringSurvey, dtype: float64
# <Axes: ylabel='ParentAnsweringSurvey'>

# %%
fig, axarr=plt.subplots(2,2,figsize=(10,10))
sns.countplot(x='Class',data=data,ax=axarr[0,0])
sns.countplot(x='gender',data=data,ax=axarr[0,1])
sns.countplot(x='StageID',data=data,ax=axarr[1,0])
sns.countplot(x='Semester',data=data,ax=axarr[1,1])
# Out:
# <Axes: xlabel='Semester', ylabel='count'>

# %%
fig,axrr=plt.subplots(2,2,figsize=(10,10))
sns.countplot(x='gender', hue='Class',data=data, ax=axrr[0,0],order=['M','F'],hue_order=['L','M','H'])
sns.countplot(x='gender', hue='Relation',data=data, ax=axrr[0,1],order=['M','F'])
sns.countplot(x='gender', hue='Topic',data=data, ax=axrr[1,0],order=['M','F'])
sns.countplot(x='gender', hue='StageID',data=data, ax=axrr[1,1],order=['M','F'])
# Out:
# <Axes: xlabel='gender', ylabel='count'>

# %%
fig, (axis1,axis2)=plt.subplots(1,2,figsize=(20,6))
sns.countplot(x='NationalITy',hue='Relation',data=data,ax=axis1)
sns.countplot(x='NationalITy',hue='Relation',data=data,ax=axis1)
# Out:
# <Axes: xlabel='NationalITy', ylabel='count'>

# %%
plt.scatter(data['raisedhands'],data['VisITedResources'])

# %%
fig,axrr=plt.subplots(2,2,figsize=(10,10))
sns.barplot(x='Class',y='VisITedResources',data=data,order=['L','M','H'],ax=axrr[0,0])
sns.barplot(x='Class',y='raisedhands',data=data,order=['L','M','H'],ax=axrr[0,1])
sns.barplot(x='Class',y='AnnouncementsView',data=data,order=['L','M','H'],ax=axrr[1,0])
sns.barplot(x='Class',y='Discussion',data=data,order=['L','M','H'],ax=axrr[1,1])
# Out:
# <Axes: xlabel='Class', ylabel='Discussion'>

# %%
fig,(axis1,axis2)=plt.subplots(1,2,figsize=(10,5))
sns.barplot(x='gender',y='raisedhands',data=data,ax=axis1)
sns.barplot(x='gender',y='Discussion',data=data,ax=axis2)
# Out:
# <Axes: xlabel='gender', ylabel='Discussion'>

# %%
fig,(axis1,axis2)=plt.subplots(1,2,figsize=(10,10))
sns.swarmplot(x='gender',y='raisedhands',data=data,ax=axis1)
sns.swarmplot(x='gender',y='AnnouncementsView',data=data,ax=axis2)
# Out:
# <Axes: xlabel='gender', ylabel='AnnouncementsView'>

# %%
fig,(axis1,axis2)=plt.subplots(1,2,figsize=(10,5))
sns.boxplot(x='Class',y='raisedhands',data=data,ax=axis1)
sns.boxplot(x='Class',y='AnnouncementsView',data=data,ax=axis2)
# Out:
# <Axes: xlabel='Class', ylabel='AnnouncementsView'>

# %%
#point plotting
fig,(axis1,axis2)=plt.subplots(1,2)
sns.pointplot(x='gender',y='raisedhands',hue='Semester',data=data,ax=axis1)
sns.pointplot(x='gender',y='Discussion',hue='Semester',data=data,ax=axis2)
# Out:
# <Axes: xlabel='gender', ylabel='Discussion'>

# %%
fig,(axis1,axis2)=plt.subplots(1,2,figsize=(10,4))
sns.regplot(x='raisedhands',y='VisITedResources',data=data,ax=axis1)
sns.regplot(x='Discussion',y='AnnouncementsView',data=data,ax=axis2)
# Out:
# <Axes: xlabel='Discussion', ylabel='AnnouncementsView'>

# %%
plot=sns.countplot(x='Class',hue='Relation',data=data,palette='Set1')
plot.set(xlabel='Class',ylabel='Count',title='Gender comparison')
plt.show()

# %%
sns.pairplot(data,hue='Class')

# %%
sns.pairplot(data,hue='VisITedResources')

# %%
Features=data.drop('gender',axis=1)
Target=data['gender']
label=LabelEncoder()
Cat_Colums=Features.dtypes.pipe(lambda Features:Features[Features=='object']).index
for col in Cat_Colums:
    Features[col]=label.fit_transform(Features[col])
print(Features)
# Out:
#      NationalITy  PlaceofBirth  StageID  GradeID  SectionID  Topic  Semester  \
# 0              4             4        2        1          0      7         0
# 1              4             4        2        1          0      7         0
# 2              4             4        2        1          0      7         0
# 3              4             4        2        1          0      7         0
# 4              4             4        2        1          0      7         0
# ..           ...           ...      ...      ...        ...    ...       ...
# 475            3             3        1        5          0      2         1
# 476            3             3        1        5          0      5         0
# 477            3             3        1        5          0      5         1
# 478            3             3        1        5          0      6         0
# 479            3             3        1        5          0      6         1
#
# ...

# %%
Features=data.drop('Relation',axis=1)
Target=data['Relation']
label=LabelEncoder()
Colums=Features.dtypes.pipe(lambda Features:Features[Features=='object']).index
for col in Colums:
    Features[col]=label.fit_transform(Features[col])
print(Features)
# Out:
#      gender  NationalITy  PlaceofBirth  StageID  GradeID  SectionID  Topic  \
# 0         1            4             4        2        1          0      7
# 1         1            4             4        2        1          0      7
# 2         1            4             4        2        1          0      7
# 3         1            4             4        2        1          0      7
# 4         1            4             4        2        1          0      7
# ..      ...          ...           ...      ...      ...        ...    ...
# 475       0            3             3        1        5          0      2
# 476       0            3             3        1        5          0      5
# 477       0            3             3        1        5          0      5
# 478       0            3             3        1        5          0      6
# 479       0            3             3        1        5          0      6
#
# ...

# %%
Features=data.drop('StudentAbsenceDays',axis=1)
Target=data['StudentAbsenceDays']
label=LabelEncoder()
Colums=Features.dtypes.pipe(lambda Features:Features[Features=='object']).index
for col in Colums:
    Features[col]=label.fit_transform(Features[col])
print(Features)
# Out:
#      gender  NationalITy  PlaceofBirth  StageID  GradeID  SectionID  Topic  \
# 0         1            4             4        2        1          0      7
# 1         1            4             4        2        1          0      7
# 2         1            4             4        2        1          0      7
# 3         1            4             4        2        1          0      7
# 4         1            4             4        2        1          0      7
# ..      ...          ...           ...      ...      ...        ...    ...
# 475       0            3             3        1        5          0      2
# 476       0            3             3        1        5          0      5
# 477       0            3             3        1        5          0      5
# 478       0            3             3        1        5          0      6
# 479       0            3             3        1        5          0      6
#
# ...

# %%
Features=data.drop('Class',axis=1)
Target=data['Class']
label=LabelEncoder()
Colums=Features.dtypes.pipe(lambda Features:Features[Features=='object']).index
for col in Colums:
    Features[col]=label.fit_transform(Features[col])
print(Features)
# Out:
#      gender  NationalITy  PlaceofBirth  StageID  GradeID  SectionID  Topic  \
# 0         1            4             4        2        1          0      7
# 1         1            4             4        2        1          0      7
# 2         1            4             4        2        1          0      7
# 3         1            4             4        2        1          0      7
# 4         1            4             4        2        1          0      7
# ..      ...          ...           ...      ...      ...        ...    ...
# 475       0            3             3        1        5          0      2
# 476       0            3             3        1        5          0      5
# 477       0            3             3        1        5          0      5
# 478       0            3             3        1        5          0      6
# 479       0            3             3        1        5          0      6
#
# ...

# %%
Features=data.drop('PlaceofBirth',axis=1)
Target=data['PlaceofBirth']
label=LabelEncoder()
Colums=Features.dtypes.pipe(lambda Features:Features[Features=='object']).index
for col in Colums:
    Features[col]=label.fit_transform(Features[col])
print(Features)
# Out:
#      gender  NationalITy  StageID  GradeID  SectionID  Topic  Semester  \
# 0         1            4        2        1          0      7         0
# 1         1            4        2        1          0      7         0
# 2         1            4        2        1          0      7         0
# 3         1            4        2        1          0      7         0
# 4         1            4        2        1          0      7         0
# ..      ...          ...      ...      ...        ...    ...       ...
# 475       0            3        1        5          0      2         1
# 476       0            3        1        5          0      5         0
# 477       0            3        1        5          0      5         1
# 478       0            3        1        5          0      6         0
# 479       0            3        1        5          0      6         1
#
#      Relation  raisedhands  VisITedResources  AnnouncementsView  Discussion  \
# ...

# %%
Features=data.drop('ParentschoolSatisfaction',axis=1)
Target=data['ParentschoolSatisfaction']
label=LabelEncoder()
Colums=Features.dtypes.pipe(lambda Features:Features[Features=='object']).index
for col in Colums:
    Features[col]=label.fit_transform(Features[col])
print(Features)
# Out:
#      gender  NationalITy  PlaceofBirth  StageID  GradeID  SectionID  Topic  \
# 0         1            4             4        2        1          0      7
# 1         1            4             4        2        1          0      7
# 2         1            4             4        2        1          0      7
# 3         1            4             4        2        1          0      7
# 4         1            4             4        2        1          0      7
# ..      ...          ...           ...      ...      ...        ...    ...
# 475       0            3             3        1        5          0      2
# 476       0            3             3        1        5          0      5
# 477       0            3             3        1        5          0      5
# 478       0            3             3        1        5          0      6
# 479       0            3             3        1        5          0      6
#
# ...

# %%
Features=data.drop('StageID',axis=1)
Target=data['StageID']
label=LabelEncoder()
Colums=Features.dtypes.pipe(lambda Features:Features[Features=='object']).index
for col in Colums:
    Features[col]=label.fit_transform(Features[col])
print(Features)
# Out:
#      gender  NationalITy  PlaceofBirth  GradeID  SectionID  Topic  Semester  \
# 0         1            4             4        1          0      7         0
# 1         1            4             4        1          0      7         0
# 2         1            4             4        1          0      7         0
# 3         1            4             4        1          0      7         0
# 4         1            4             4        1          0      7         0
# ..      ...          ...           ...      ...        ...    ...       ...
# 475       0            3             3        5          0      2         1
# 476       0            3             3        5          0      5         0
# 477       0            3             3        5          0      5         1
# 478       0            3             3        5          0      6         0
# 479       0            3             3        5          0      6         1
#
# ...

# %%
Features=data.drop('GradeID',axis=1)
Target=data['GradeID']
label=LabelEncoder()
Colums=Features.dtypes.pipe(lambda Features:Features[Features=='object']).index
for col in Colums:
    Features[col]=label.fit_transform(Features[col])
print(Features)
# Out:
#      gender  NationalITy  PlaceofBirth  StageID  SectionID  Topic  Semester  \
# 0         1            4             4        2          0      7         0
# 1         1            4             4        2          0      7         0
# 2         1            4             4        2          0      7         0
# 3         1            4             4        2          0      7         0
# 4         1            4             4        2          0      7         0
# ..      ...          ...           ...      ...        ...    ...       ...
# 475       0            3             3        1          0      2         1
# 476       0            3             3        1          0      5         0
# 477       0            3             3        1          0      5         1
# 478       0            3             3        1          0      6         0
# 479       0            3             3        1          0      6         1
#
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
x_train,x_test,y_train,y_test=train_test_split(Features,Target,test_size=0.2,random_state=52)
print(x_train)
print(x_test)
print(y_train)
print(y_test)
# Out:
#      gender  NationalITy  PlaceofBirth  StageID  SectionID  Topic  Semester  \
# 299       1            3             3        2          0     10         1
# 348       1            5             5        2          1      4         0
# 162       0            3             3        2          1      4         1
# 467       0            3             3        1          0      5         1
# 306       1            3             3        2          1     10         0
# ..      ...          ...           ...      ...        ...    ...       ...
# 86        1            8             8        2          1      7         0
# 151       1            8            11        0          0     10         1
# 13        1           12            12        1          0      8         0
# 267       1            3             3        1          0      3         1
# 156       0           10            11        0          1      4         1
#
# ...

# %%
Logit_Model=LogisticRegression()
Logit_Model.fit(x_train,y_train)
# Out:
# e:\anaconda\envs\myenv\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score
Prediction=Logit_Model.predict(x_test)
score = accuracy_score(y_test,Prediction)
Report=classification_report(y_test,Prediction)
# Out:
# e:\anaconda\envs\myenv\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# e:\anaconda\envs\myenv\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# e:\anaconda\envs\myenv\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
print(Prediction)
# Out:
# ['G-02' 'G-08' 'G-02' 'G-07' 'G-08' 'G-04' 'G-08' 'G-08' 'G-07' 'G-02'
#  'G-07' 'G-07' 'G-08' 'G-07' 'G-07' 'G-02' 'G-08' 'G-08' 'G-07' 'G-08'
#  'G-02' 'G-02' 'G-02' 'G-04' 'G-02' 'G-04' 'G-02' 'G-08' 'G-08' 'G-02'
#  'G-08' 'G-07' 'G-02' 'G-07' 'G-02' 'G-12' 'G-02' 'G-02' 'G-07' 'G-11'
#  'G-08' 'G-08' 'G-08' 'G-02' 'G-08' 'G-02' 'G-08' 'G-04' 'G-02' 'G-07'
#  'G-08' 'G-04' 'G-02' 'G-02' 'G-08' 'G-02' 'G-08' 'G-02' 'G-02' 'G-08'
#  'G-02' 'G-08' 'G-08' 'G-02' 'G-08' 'G-08' 'G-02' 'G-02' 'G-08' 'G-02'
#  'G-07' 'G-08' 'G-08' 'G-08' 'G-02' 'G-07' 'G-02' 'G-02' 'G-04' 'G-02'
#  'G-02' 'G-08' 'G-07' 'G-07' 'G-02' 'G-07' 'G-02' 'G-07' 'G-04' 'G-08'
#  'G-02' 'G-02' 'G-07' 'G-08' 'G-08' 'G-08']

# %%
print('score :',score)
# Out:
# score : 0.53125

# %%
print('Report',Report)
# Out:
# Report               precision    recall  f1-score   support
#
#         G-02       0.64      1.00      0.78        23
#         G-04       0.43      0.30      0.35        10
#         G-05       0.00      0.00      0.00         1
#         G-06       0.00      0.00      0.00         6
#         G-07       0.44      0.38      0.41        21
#         G-08       0.52      0.61      0.56        28
#         G-09       0.00      0.00      0.00         2
#         G-10       0.00      0.00      0.00         1
#         G-11       0.00      0.00      0.00         3
#         G-12       0.00      0.00      0.00         1
#
#     accuracy                           0.53        96
#    macro avg       0.20      0.23      0.21        96
# weighted avg       0.45      0.53      0.48        96
